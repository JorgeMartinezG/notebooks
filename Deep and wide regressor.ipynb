# %%
import pandas as pd
import tensorflow as tf

# %% [markdown]
# ### Load pandas dataset

# %%
df = pd.read_csv('/code/geosure/mdf20181119.tsv', encoding='utf-16', sep='\t')
df.head()
# Out:
#    geosure_id  record        continent wiki_continent              country  \
# 0  Q930100001       1  Central America         Q27611        Anguilla (UK)
# 1  Q930100002       2  Central America         Q27611  Antigua and Barbuda
# 2  Q930100003       3  Central America         Q27611           Aruba (ND)
# 3  Q930100004       4  Central America         Q27611           Aruba (ND)
# 4  Q930100005       5  Central America         Q27611           Aruba (ND)
#
#   wiki_country country_code province wiki_city           city  ...    \
# 0         Q145           AI      NaN    Q30994     The Valley  ...
# 1         Q781           AG      NaN    Q36262     St. John's  ...
# 2       Q21203           AW      NaN   Q131243     Oranjestad  ...
# 3       Q21203           AW      NaN  Q3558364     Santa Cruz  ...
# 4       Q21203           AW      NaN  Q2605285  Santa Nicolas  ...
#
#   population   latitude  longitude composite physical women  theft  political  \
# ...

# %% [markdown]
# ### Get data for Argentina only

# %%
df_arg = df.loc[df['country'] == 'Argentina'].reset_index()

# %%
# Out:
# '0.12.0'
